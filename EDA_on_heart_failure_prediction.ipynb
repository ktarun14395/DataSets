# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heart_data=pd.read_csv('heart_failure_clinical_records.csv')

# %%
heart_data
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0     55.0        0                       748         0                 45
# 1     65.0        0                        56         0                 25
# 2     45.0        0                       582         1                 38
# 3     60.0        1                       754         1                 40
# 4     95.0        1                       582         0                 30
# ...    ...      ...                       ...       ...                ...
# 4995  45.0        0                       582         1                 55
# 4996  60.0        1                       582         0                 30
# 4997  95.0        1                       112         0                 40
# 4998  65.0        1                       160         1                 20
# 4999  40.0        0                       244         0                 45
#
# ...

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       5000 non-null   float64
#  1   anaemia                   5000 non-null   int64
#  2   creatinine_phosphokinase  5000 non-null   int64
#  3   diabetes                  5000 non-null   int64
#  4   ejection_fraction         5000 non-null   int64
#  5   high_blood_pressure       5000 non-null   int64
#  6   platelets                 5000 non-null   float64
#  7   serum_creatinine          5000 non-null   float64
#  8   serum_sodium              5000 non-null   int64
#  9   sex                       5000 non-null   int64
#  10  smoking                   5000 non-null   int64
#  11  time                      5000 non-null   int64
#  12  DEATH_EVENT               5000 non-null   int64
# dtypes: float64(3), int64(10)
# ...

# %%
heart_data.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
heart_data.duplicated().sum()
# Out:
# 3680

# %%
heart_data=heart_data.drop_duplicates()
heart_data
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0     55.0        0                       748         0                 45
# 1     65.0        0                        56         0                 25
# 2     45.0        0                       582         1                 38
# 3     60.0        1                       754         1                 40
# 4     95.0        1                       582         0                 30
# ...    ...      ...                       ...       ...                ...
# 4731  75.0        0                       582         1                 30
# 4855  73.0        0                       582         0                 20
# 4862  45.0        0                       220         0                 35
# 4965  40.0        1                       129         1                 35
# 4972  70.0        0                       835         0                 35
#
# ...

# %%
heart_data.shape
# Out:
# (1320, 13)

# %%
plt.figure(figsize=(10,6))
sns.histplot(heart_data['age'],kde=True,color='blue')
plt.title('Distribution of age')
plt.xlabel('age')
plt.ylabel('frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=heart_data,x='sex',palette='viridis')
plt.title('Gender Distribution')
plt.xlabel('sex(0:female,1:male)')
plt.ylabel('count')
plt.show()
# Out:
# <ipython-input-17-b591521b7cdf>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=heart_data,x='sex',palette='viridis')

# %%
plt.figure(figsize=(12,8))
correlation_matrix=heart_data.corr()
sns.heatmap(correlation_matrix,annot=True,fmt=".2f",cmap='viridis',vmin=-1,vmax=1,center=0,square=True,linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=heart_data,x='DEATH_EVENT',y='serum_creatinine',palette='viridis')
plt.title('Serum Creatinine Levels by Death Event')
plt.xlabel('Death Event(0:No,1:Yes)')
plt.ylabel('Serum Creatinine')
plt.show()
# Out:
# <ipython-input-29-64bff56b65ee>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=heart_data,x='DEATH_EVENT',y='serum_creatinine',palette='viridis')
